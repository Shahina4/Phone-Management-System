# %%
class Phone():
    def __init__(self, brand, model, variant, color, specifications):
        self.brand = brand
        self.model = model
        self.variant = variant
        self.color = color
        self.specifications = specifications
        self.freeAccessories = False
        self.discount = 0
    def getAccessories(self):
        if self.variant == '1 TB':
            self.freeAccessories = True
        if self.freeAccessories:
            print(f'Offer: Get free accessories')
    def getDiscount(self):
        if self.specifications['Price'] > 120000:
            print(f'Actual Price: {self.specifications['Price']}')
            self.discount = 0.10
            print(f'Offer: {int(self.discount*100)}% Discount')
    def totalPrice(self):
        self.finalPrice = self.specifications["Price"]*(1-self.discount)
        return int(self.finalPrice)
    def displaySpecifications(self):
        print(f'\n*****{self.model} Specifications*****')
        print(f'Brand: {self.brand}')
        print(f'Model: {self.model}')
        print(f'Variant: {self.variant}')
        print(f'Color: {self.color}')
        for property, value in self.specifications.items():
            if property == "Price":
                continue
            print(f'{property}: {value}')
        self.getAccessories()
        self.getDiscount()
        print('Final Price:', self.totalPrice())        
appleFiveTwelveGB = {
                        'iPhone 15':{
                                    'Battery':'3349 mAh Li-ion',
                                    'Camera':'48 MP Main Camera',
                                    'Size':'6.7 Inches',
                                    'Display': '6.7" Super Retina XDR display',
                                    'OS' : 'iOS 17',
                                    'Price': 110000
                                   },
                        'iPhone 16':{
                                     'Battery':'3561 mAh A 18 Chip',
                                     'Camera':'48 MP Fusion Camera',
                                     'Size':'6.7 Inches',
                                     'Display': '6.7" Super Retina XDR display',
                                     'OS' : 'iOS',
                                     'Price': 108900
                                    },
                        'iPhone 16 Promax':{
                                             'Battery':'4685 mAh Huge Leap',
                                             'Camera':'48 MP Main Camera',
                                             'Size':'6.9 Inches',
                                             'Display': '6.9" Super Retina XDR display',
                                             'OS' : 'iOS 17',
                                             'Price': 154900
                                            }
                    }

appleOneTB = {
                'iPhone 15':{
                            'Battery':'3349 mAh Li-ion',
                            'Camera':'48 MP Main Camera',
                            'Size':'6.7 Inches',
                            'Display': '6.7" Super Retina XDR display',
                            'OS' : 'iOS 17',
                            'Price': 125900
                            },
                'iPhone 16':{
                            'Battery':'3561 mAh A 18 Chip',
                            'Camera':'48 MP Fusion Camera',
                            'Size':'6.7 Inches',
                            'Display': '6.7" Super Retina XDR display',
                            'OS' : 'iOS',
                            'Price': 177900
                            },
                'iPhone 16 Promax':{
                                     'Battery':'4685 mAh Huge Leap',
                                     'Camera':'48 MP Main Camera',
                                     'Size':'6.9 Inches',
                                     'Display': '6.9" Super Retina XDR display',
                                     'OS' : 'iOS 17',
                                     'Price': 184900
                                    }
            }
samsungFiveTwelveGB = {
                        'Galaxy S25 Ultra':{
                                            'Battery':'5000 mAh Li-ion',
                                            'Camera':'50 MP Ultra-wide',
                                            'Size':'6.9 Inches',
                                            'Display': '6.9" QHD + Dynamic AMOLED 2X',
                                            'OS' : 'Android 15 with One UI 7',
                                            'Price': 139999
                                           },
                        'Galaxy A56 5G':{
                                         'Battery':'5000 mAh, 45 W fast charge',
                                         'Camera':'12 MP Ultra-wide',
                                         'Size':'6.7 Inches',
                                         'Display': '6.7" FHD + Super AMOLED',
                                         'OS' : 'Android 15 + One UI 7',
                                         'Price': 41999
                                        },
                        'Galaxy Note 20':{
                                          'Battery':'4300 mAh 25W Super Fast',
                                          'Camera':'12 MP Wide',
                                          'Size':'6.7 Inches',
                                          'Display': '6.7" Super AMOLED plus',
                                          'OS' : 'Android 10 + One UI 2.5',
                                          'Price': 97300
                                        }
                    }

samsungOneTB = {
                'Galaxy S25 Ultra':{
                                    'Battery':'5000 mAh Li-ion',
                                    'Camera':'200 MP Main Sensor',
                                    'Size':'6.9 Inches',
                                    'Display': '6.9" QHD + Dynamic AMOLED 2X',
                                    'OS' : 'Android 15 with One UI 7',
                                    'Price': 159999
                                  },
                'Galaxy A56 5G':{
                                 'Battery':'5000 mAh, 45 W fast charge',
                                 'Camera':'50 MP (OIS) wide',
                                 'Size':'6.7 Inches',
                                 'Display': '6.7" FHD + Super AMOLED',
                                 'OS' : 'Android 15 + One UI 7',
                                 'Price': 47999
                                },
                'Galaxy Note 20':{
                                  'Battery':'4500 mAh 25W Super Fast',
                                  'Camera':'108 MP Main (OIS)',
                                  'Size':'6.9 Inches',
                                  'Display': '6.9" Dynamic AMOLED 2X',
                                  'OS' : 'Android 10 + One UI 2.5',
                                  'Price': 112300
                                }
               }
invalidChoice = 0
invalidBrand = 0
invalidModel = 0
invalidVariant = 0
invalidColor = 0
color_input = ''
while True:
    choice = input("Do you want a phone?\n1. Yes\n2. No\n")
    if choice == '1' or choice.lower() == 'yes':
        while True:
            brand_input = input("Which brand do you want?\n1. Apple\n2. Samsung\n")
            if brand_input == '1' or brand_input.lower() == 'apple':
                brand_input = 'Apple'
                while True:
                    print("\nAvailable models: \n1. iPhone 15 \n2. iPhone 16\n3. iPhone 16 Promax")
                    model_input = input("Choose model:")
                    if model_input == '1' or model_input.lower() == 'iphone 15' or model_input.lower() == 'iphone15':
                        model_input = 'iPhone 15'
                    elif model_input == '2' or model_input.lower() == 'iphone 16' or model_input.lower() == 'iphone16':
                        model_input = 'iPhone 16'
                    elif model_input == '3' or model_input.lower() == 'iphone 16 promax' or model_input.lower() == 'iphone16promax':
                        model_input = 'iPhone 16 Promax'
                    else:
                        invalidModel += 1
                        if invalidModel == 3:
                            print("Invalid model selected")
                            break
                        print("Please select available model")    
                    while model_input in ('iPhone 15','iPhone 16','iPhone 16 Promax'):
                        print('\nAvailable Variants: \n1.512 GB\n2.1 TB')
                        variant_input = input("Which one you will select:")
                        if variant_input == '1' or variant_input.lower() == '512 gb' or variant_input.lower() == '512gb':
                            variant_input = '512 GB'
                        elif variant_input == '2' or variant_input.lower() == '1 tb' or variant_input.lower() == '1tb':
                            variant_input = '1 TB'
                        else:
                            invalidVariant += 1
                            if invalidVariant == 3:
                                print("Invalid variant selected")
                                break
                            print("Please select available variant")
                        while variant_input in ('512 GB','1 TB'):
                            print('\nColors available:\n1.Blue\n2.Black\n3.White\n4.Gold')
                            color_input = input("Which one you will select:")
                            if color_input == '1' or color_input.lower() == 'blue':
                                color_input = 'Blue'
                            elif color_input == '2' or color_input.lower() == 'black':
                                color_input = 'Black'
                            elif color_input == '3' or color_input.lower() == 'white':
                                color_input = 'White'
                            elif color_input == '4' or color_input.lower() == 'gold':
                                color_input = 'Gold'
                            else:
                                invalidColor += 1
                                if invalidColor == 3:
                                    print("Invalid color selected")
                                    break
                                print("Please select available color")
                                continue
                            if color_input in ('Blue', 'Black', 'White', 'Gold'):
                                if variant_input == '512 GB':
                                    phoneSpecifications = appleFiveTwelveGB[model_input]
                                else:
                                    phoneSpecifications = appleOneTB[model_input]
                                purchase = Phone(brand_input, model_input, variant_input, color_input, phoneSpecifications)
                                purchase.displaySpecifications()
                                break
                        if invalidColor == 3 or color_input in ('Blue', 'Black', 'White', 'Gold'):
                            break
                    if invalidColor == 3 or invalidVariant == 3 or color_input in ('Blue', 'Black', 'White', 'Gold'):
                        break
                if invalidColor == 3 or invalidVariant == 3 or invalidModel == 3 or color_input in ('Blue', 'Black', 'White', 'Gold'):
                    break
            elif brand_input == '2' or brand_input.lower() == 'samsung':
                brand_input = 'Samsung'
                while True:
                    print("\nAvailable models: \n1. Galaxy S25 Ultra\n2. Galaxy A56 5G\n3. Galaxy Note 20")
                    model_input = input("Choose model:")
                    if model_input == '1' or model_input.lower() == 'galaxy s25 ultra' or model_input.lower() == 'galaxys25ultra':
                        model_input = 'Galaxy S25 Ultra'
                    elif model_input == '2' or model_input.lower() == 'galaxy a56 5g' or model_input.lower() == 'galaxya565g':
                        model_input = 'Galaxy A56 5G'
                    elif model_input == '3' or model_input.lower() == 'galaxy note 20' or model_input.lower() == 'galaxynote20':
                        model_input = 'Galaxy Note 20'
                    else:
                        invalidModel += 1
                        if invalidModel == 3:
                            print("Invalid model selected")
                            break
                        print("Please select available model")    
                    while model_input in ('Galaxy S25 Ultra','Galaxy A56 5G','Galaxy Note 20'):
                        print('\nAvailable Variants: \n1.512 GB\n2.1 TB')
                        variant_input = input("Which one you will select:")
                        if variant_input == '1' or variant_input.lower() == '512 gb' or variant_input.lower() == '512gb':
                            variant_input = '512 GB'
                        elif variant_input == '2' or variant_input.lower() == '1 tb' or variant_input.lower() == '1tb':
                            variant_input = '1 TB'
                        else:
                            invalidVariant += 1
                            if invalidVariant == 3:
                                print("Invalid variant selected")
                                break
                            print("Please select available variant")
                        while variant_input in ('512 GB','1 TB'):
                            print('\nColors available:\n1.Blue\n2.Black\n3.White\n4.Gold')
                            color_input = input("Which one you will select:")
                            if color_input == '1' or color_input.lower() == 'blue':
                                color_input = 'Blue'
                            elif color_input == '2' or color_input.lower() == 'black':
                                color_input = 'Black'
                            elif color_input == '3' or color_input.lower() == 'white':
                                color_input = 'White'
                            elif color_input == '4' or color_input.lower() == 'gold':
                                color_input = 'Gold'
                            else:
                                invalidColor += 1
                                print("Please select available color")
                                if invalidColor == 3:
                                    break
                            if color_input in ('Blue', 'Black', 'White', 'Gold'):
                                if variant_input == '512 GB':
                                    phoneSpecifications = samsungFiveTwelveGB[model_input]
                                else:
                                    phoneSpecifications = samsungOneTB[model_input]
                                purchase = Phone(brand_input, model_input, variant_input, color_input, phoneSpecifications)
                                purchase.displaySpecifications()
                                break
                        if invalidColor == 3 or color_input in ('Blue', 'Black', 'White', 'Gold'):
                            break
                    if invalidColor == 3 or invalidVariant == 3 or color_input in ('Blue', 'Black', 'White', 'Gold'):
                        break
                if invalidColor == 3 or invalidVariant == 3 or invalidModel == 3 or color_input in ('Blue', 'Black', 'White', 'Gold'):
                    break
            else:
                invalidBrand += 1
                if invalidBrand == 3:
                    print("Invalid brand selected")
                    break
                print("Please select available brand")
        if invalidBrand == 3 or invalidModel == 3 or invalidVariant == 3 or invalidColor == 3 or color_input in ('Blue', 'Black', 'White', 'Gold'):
            break
    elif choice == '2' or choice.lower() == 'no':
        print("Thank You. Visit Again!")
        break
    else:
        invalidChoice += 1
        if invalidChoice == 3:
            print("Invalid Choice")
            break
        print("Please select valid choice")
# Out:
# Do you want a phone?
# 1. Yes
# 2. No
#  yeah
# Please select valid choice
# Do you want a phone?
# 1. Yes
# 2. No
#  s
# Please select valid choice
# Do you want a phone?
# 1. Yes
# 2. No
#  yes
# Which brand do you want?
# 1. Apple
# 2. Samsung
#  appple
# Please select available brand
# Which brand do you want?
# 1. Apple
# 2. Samsung
#  aPPlE
# Available models:
# 1. iPhone 15
# 2. iPhone 16
# 3. iPhone 16 Promax
# Choose model: iphonesixteen
# Please select available model
#
# Available models:
# 1. iPhone 15
# 2. iPhone 16
# 3. iPhone 16 Promax
# Choose model: Iphone116
# Please select available model
#
# Available models:
# 1. iPhone 15
# 2. iPhone 16
# 3. iPhone 16 Promax
# Choose model: iPHone16
# Available Variants:
# 1.512 GB
# 2.1 TB
# Which one you will select: 513gb
# Please select available variant
#
# Available Variants:
# 1.512 GB
# 2.1 TB
# Which one you will select: 1tb
# Colors available:
# 1.Blue
# 2.Black
# 3.White
# 4.Gold
# Which one you will select: goldd
# ...
